# %%
### Pegar a nota da prova teorica
### Pedir pro usuario
### Pedir pro usuario a nota da prova pratica
### Calcule a media 
### se a nota for maior ou igual a 7, print("aprovado")
### Se não, reprovado


print("| ______________________________ |")
print("| CALCULO DE MEDIAS              |")
print("| ______________________________ |")


nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))

media = (nota1 + nota2) / 2
aprovado = (media > 7) and (nota1 != 0) and (nota2 != 0)


if media >= 7:
    print("| Aluno aprovado")
else:
    print("| Aluno reprovado")
# Out:
# | ______________________________ |
# | CALCULO DE MEDIAS              |
# | ______________________________ |
# | Aluno aprovado

# %%
## Listas vazias

artistas = []
musicas = []

### Pergunte a quantidade de musica a ser adicionada a playlist
### Pergunte o nome do artista e o nome da musica
### Depois de adicionar nas litas, de um print mostrando os artistas e as musicas
### Se tiver Pablo Vittar, print(Alerrandro curte)

repeticao = int(input("Digite a quantdade de musicas na sua playlist"))

for repeticao in range(repeticao):
    musica = input("Digite o nome de uma musica")
    artista = input("Digite o nome de um artista")

    musicas.append(musica)
    artistas.append(artista)

print(f'''A sua playlist foi criada:)
musicas: {musicas}
artistas: {artistas}''')

if musica == 'Pablo Vittar':
    print('Alejandro Curte')

else:
    print('')
# Out:
# A sua playlist foi criada:)
# musicas: ['2 much', 'K.O']
# artistas: ['Justin Bieber', 'Pablo Vittar']
